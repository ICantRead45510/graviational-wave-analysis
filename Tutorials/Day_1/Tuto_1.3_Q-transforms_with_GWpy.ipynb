# %% [markdown]
# <a href="https://colab.research.google.com/github/ICantRead45510/graviational-wave-analysis/blob/main/Tutorials/Day_1/Tuto_1.3_Q-transforms_with_GWpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img style="float: left;padding: 1.3em" src="https://raw.githubusercontent.com/gw-odw/odw-2023/main/Tutorials/logo.png">
#
# #  Gravitational Wave Open Data Workshop #6
#
#
# #### Tutorial 1.3: Data representations in GWpy
#
# This notebook covers some different ways of representing data, including
#
#   - the spectrogram
#   - the Q-transform
#
# with a challenge you can explore for each method.
#
# [Click this link to view this tutorial in Google Colaboratory](https://colab.research.google.com/github/gw-odw/odw-2023/blob/main/Tutorials/Day_1/Tuto_1.3_Q-transforms_with_GWpy.ipynb)

# %% [markdown]
# ##  Installation  (execute only if running on a cloud platform, like Google Colab, or if you haven't done the installation already!)
#
# Note: we use [`pip`](https://docs.python.org/3.6/installing/), but **it is recommended** to use [conda](https://docs.ligo.org/lscsoft/conda/) on your own machine, as explained in the [installation instructions](https://github.com/gw-odw/odw-2021/blob/master/setup.md). This usage might look a little different than normal, simply because we want to do this directly from the notebook.

# %%
# -- Uncomment following line if running in Google Colab
# !pip uninstall -y numba gwpy astropy numpy matplotlib

# !pip install --upgrade pip setuptools wheel
# !pip install --upgrade --force-reinstall "numpy==2.0.0"
# !pip install --upgrade --force-reinstall "numba==0.59.0"
# !pip install "astropy==6.0.0"
# !pip install "matplotlib==3.8.0"
# !pip install "gwpy==3.0.7"
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Found existing installation: numba 0.59.0
# Uninstalling numba-0.59.0:
#   Successfully uninstalled numba-0.59.0
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Found existing installation: gwpy 3.0.7
# Uninstalling gwpy-3.0.7:
#   Successfully uninstalled gwpy-3.0.7
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Found existing installation: astropy 6.0.0
# Uninstalling astropy-6.0.0:
#   Successfully uninstalled astropy-6.0.0
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Found existing installation: matplotlib 3.8.0
# Uninstalling matplotlib-3.8.0:
#   Successfully uninstalled matplotlib-3.8.0
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (26.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (83.0.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.47.0)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from wheel) (26.2)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Collecting numpy==2.0.0
#   Using cached numpy-2.0.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Using cached numpy-2.0.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.0 MB)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# splot 1.1.7 requires matplotlib>=3.3.3, which is not installed.
# geemap 0.38.3 requires matplotlib, which is not installed.
# umap-learn 0.5.12 requires numba>=0.51.2, which is not installed.
# wordcloud 1.9.6 requires matplotlib, which is not installed.
# librosa 0.11.0 requires numba>=0.51.0, which is not installed.
# quantecon 0.11.3 requires numba>=0.49.0, which is not installed.
# pytensor 2.38.3 requires numba<=0.65.1,>=0.58, which is not installed.
# pointpats 2.5.5 requires matplotlib>=3.9, which is not installed.
# mlxtend 0.23.4 requires matplotlib>=3.0.0, which is not installed.
# arviz 0.22.0 requires matplotlib>=3.8, which is not installed.
# missingno 0.5.2 requires matplotlib, which is not installed.
# seaborn 0.13.2 requires matplotlib!=3.6.1,>=3.4, which is not installed.
# prophet 1.3.0 requires matplotlib>=2.0.0, which is not installed.
# yellowbrick 1.5 requires matplotlib!=3.0.0,>=2.0.2, which is not installed.
# pynndescent 0.6.0 requires numba>=0.55.0, which is not installed.
# matplotlib-venn 1.1.2 requires matplotlib, which is not installed.
# plotnine 0.14.5 requires matplotlib>=3.8.0, which is not installed.
# music21 9.9.2 requires matplotlib, which is not installed.
# segregation 2.5.4 requires matplotlib, which is not installed.
# segregation 2.5.4 requires numba, which is not installed.
# inequality 1.1.2 requires matplotlib>=3.8, which is not installed.
# bigframes 2.42.0 requires matplotlib>=3.7.1, which is not installed.
# stumpy 1.13.0 requires numba>=0.57.1, which is not installed.
# shap 0.52.0 requires numba; sys_platform != "darwin" or platform_machine != "x86_64", which is not installed.
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Successfully installed numpy-2.0.0
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Collecting numba==0.59.0
#   Using cached numba-0.59.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Collecting llvmlite<0.43,>=0.42.0dev0 (from numba==0.59.0)
#   Using cached llvmlite-0.42.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Collecting numpy<1.27,>=1.22 (from numba==0.59.0)
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numba-0.59.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
# Using cached llvmlite-0.42.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.8 MB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Installing collected packages: numpy, llvmlite, numba
#   Attempting uninstall: numpy
#     WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: numpy 2.0.0
#     Uninstalling numpy-2.0.0:
#       Successfully uninstalled numpy-2.0.0
#   Attempting uninstall: llvmlite
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [numpy]    WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: llvmlite 0.42.0
#     Uninstalling llvmlite-0.42.0:
#       Successfully uninstalled llvmlite-0.42.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [numba]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# splot 1.1.7 requires matplotlib>=3.3.3, which is not installed.
# geemap 0.38.3 requires matplotlib, which is not installed.
# wordcloud 1.9.6 requires matplotlib, which is not installed.
# pointpats 2.5.5 requires matplotlib>=3.9, which is not installed.
# mlxtend 0.23.4 requires matplotlib>=3.0.0, which is not installed.
# arviz 0.22.0 requires matplotlib>=3.8, which is not installed.
# missingno 0.5.2 requires matplotlib, which is not installed.
# seaborn 0.13.2 requires matplotlib!=3.6.1,>=3.4, which is not installed.
# prophet 1.3.0 requires matplotlib>=2.0.0, which is not installed.
# yellowbrick 1.5 requires matplotlib!=3.0.0,>=2.0.2, which is not installed.
# matplotlib-venn 1.1.2 requires matplotlib, which is not installed.
# plotnine 0.14.5 requires matplotlib>=3.8.0, which is not installed.
# music21 9.9.2 requires matplotlib, which is not installed.
# segregation 2.5.4 requires matplotlib, which is not installed.
# inequality 1.1.2 requires matplotlib>=3.8, which is not installed.
# bigframes 2.42.0 requires matplotlib>=3.7.1, which is not installed.
# opencv-python-headless 5.0.0.93 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 5.0.0.93 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.52.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Successfully installed llvmlite-0.42.0 numba-0.59.0 numpy-1.26.4
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Collecting astropy==6.0.0
#   Using cached astropy-6.0.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.8 kB)
# Requirement already satisfied: numpy<2,>=1.22 in /usr/local/lib/python3.12/dist-packages (from astropy==6.0.0) (1.26.4)
# Requirement already satisfied: pyerfa>=2.0 in /usr/local/lib/python3.12/dist-packages (from astropy==6.0.0) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2023.10.30.0.29.53 in /usr/local/lib/python3.12/dist-packages (from astropy==6.0.0) (0.2026.7.13.0.54.2)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.12/dist-packages (from astropy==6.0.0) (6.0.3)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.12/dist-packages (from astropy==6.0.0) (26.2)
# Using cached astropy-6.0.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.4 MB)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Installing collected packages: astropy
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Successfully installed astropy-6.0.0
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Collecting matplotlib==3.8.0
#   Using cached matplotlib-3.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.0) (1.5.0)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.0) (26.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib==3.8.0) (1.17.0)
# Using cached matplotlib-3.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Installing collected packages: matplotlib
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pointpats 2.5.5 requires matplotlib>=3.9, but you have matplotlib 3.8.0 which is incompatible.
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Successfully installed matplotlib-3.8.0
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Collecting gwpy==3.0.7
#   Using cached gwpy-3.0.7-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: astropy>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gwpy==3.0.7) (6.0.0)
# Requirement already satisfied: dqsegdb2 in /usr/local/lib/python3.12/dist-packages (from gwpy==3.0.7) (1.3.0)
# Requirement already satisfied: gwdatafind>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gwpy==3.0.7) (2.1.1)
# Requirement already satisfied: gwosc>=0.5.3 in /usr/local/lib/python3.12/dist-packages (from gwpy==3.0.7) (0.8.3)
# Requirement already satisfied: h5py>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from gwpy==3.0.7) (3.16.0)
# Requirement already satisfied: ligo-segments>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from gwpy==3.0.7) (1.4.0)
# Requirement already satisfied: ligotimegps>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from gwpy==3.0.7) (2.1.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from gwpy==3.0.7) (3.8.0)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.12/dist-packages (from gwpy==3.0.7) (1.26.4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from gwpy==3.0.7) (2.9.0.post0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from gwpy==3.0.7) (2.32.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from gwpy==3.0.7) (1.16.3)
# Requirement already satisfied: tqdm>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from gwpy==3.0.7) (4.67.3)
# Requirement already satisfied: pyerfa>=2.0 in /usr/local/lib/python3.12/dist-packages (from astropy>=4.3.0->gwpy==3.0.7) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2023.10.30.0.29.53 in /usr/local/lib/python3.12/dist-packages (from astropy>=4.3.0->gwpy==3.0.7) (0.2026.7.13.0.54.2)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.12/dist-packages (from astropy>=4.3.0->gwpy==3.0.7) (6.0.3)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.12/dist-packages (from astropy>=4.3.0->gwpy==3.0.7) (26.2)
# Requirement already satisfied: igwn-auth-utils>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from gwdatafind>=1.1.0->gwpy==3.0.7) (1.4.0)
# Requirement already satisfied: igwn-segments in /usr/local/lib/python3.12/dist-packages (from gwdatafind>=1.1.0->gwpy==3.0.7) (2.1.1)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.12/dist-packages (from gwosc>=0.5.3->gwpy==3.0.7) (9.1.4)
# Requirement already satisfied: cryptography>=44.0.1 in /usr/local/lib/python3.12/dist-packages (from igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy==3.0.7) (49.0.0)
# Requirement already satisfied: safe-netrc>=1.0 in /usr/local/lib/python3.12/dist-packages (from igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy==3.0.7) (1.0.1)
# Requirement already satisfied: scitokens>=1.8 in /usr/local/lib/python3.12/dist-packages (from igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy==3.0.7) (1.9.7)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=44.0.1->igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy==3.0.7) (2.1.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=44.0.1->igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy==3.0.7) (3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from ligo-segments>=1.0.0->gwpy==3.0.7) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->gwpy==3.0.7) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->gwpy==3.0.7) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->gwpy==3.0.7) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->gwpy==3.0.7) (1.5.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->gwpy==3.0.7) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->gwpy==3.0.7) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->gwpy==3.0.7) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->gwpy==3.0.7) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->gwpy==3.0.7) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->gwpy==3.0.7) (2026.6.17)
# Requirement already satisfied: PyJWT>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from scitokens>=1.8->igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy==3.0.7) (2.13.0)
# Requirement already satisfied: click>=6.7 in /usr/local/lib/python3.12/dist-packages (from dqsegdb2->gwpy==3.0.7) (8.4.2)
# Using cached gwpy-3.0.7-py3-none-any.whl (1.4 MB)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Installing collected packages: gwpy
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Successfully installed gwpy-3.0.7

# %% [markdown]
# **Important:** With Google Colab, you may need to restart the runtime after running the cell above.

# %% [markdown]
# ## Initialization

# %%
import gwpy

# %% [markdown]
# ## Showing the time-evolution of FFTs
#
# The FFT, and the ASD, show us a snapshot of the frequency-domain content of our signal, referred to a single time interval.
# It is commonly useful to show how this frequency-domain content evolves over time.
#
# For this we use spectrograms, which show the FFT (or ASD) at each time step on a time-frequency representation.
# The `TimeSeries` in GWpy includes two methods for this:
#
# - [`spectrogram()`](https://gwpy.github.io/docs/stable/api/gwpy.timeseries.TimeSeries.html#gwpy.timeseries.TimeSeries.spectrogram) - which includses a `stride` parameter, and shows an averaged ASD every time interval corresponding to each stride, and
# - [`spectrogram2()`](https://gwpy.github.io/docs/stable/api/gwpy.timeseries.TimeSeries.html#gwpy.timeseries.TimeSeries.spectrogram2) - shows a single-FFT ASD, defined by its `fftlength`, at each time step. These FFTs can include overlapping segments of tdata, as specified by the `overlap` parameter.
#
# Which one should I use? The short answer is use `spectrogram2()` for short(ish) chunks of data, less than a minute or so, and `spectrogram()` for longer chunks where the averaging helps remove very short noise bursts.
#
# The long answer is that averaging the FFTs computed each stride of data reduces the variance of the resulting ASD estimate. However, these averages also reduce the time resolution of the corresponding spectrogram, which is no more `fftlength` $-$ `overlap` but is now determined by the duration of the `stride`. This is called [Welch's spectral density estimation method](https://en.wikipedia.org/wiki/Welch%27s_method).
# The choice of the overalp is instead determined by how independent we want our FFTs to be (no overlap) and how dense we want them to be (`overlap` equals to a large fraction of `fftlegth`). Refer to this [GWpy example](https://gwpy.github.io/docs/stable/examples/spectrogram/spectrogram2/) on an over-dense spectrogam of GW150914.
#
# First, let's reload our data:

# %%
from gwosc.datasets import event_gps
from gwpy.timeseries import TimeSeries

gps = event_gps('GW170817')
print("GW170817 GPS:", gps)

ldata = TimeSeries.fetch_open_data('L1', int(gps)-512, int(gps)+512, cache=True)
print("GW170817 data")
print(ldata)
# Out:
# GW170817 GPS: 1187008882.4
# GW170817 data
# TimeSeries([2.06056010e-20, 1.59181918e-20, 2.18438811e-20, ...,
#             1.25504332e-19, 1.23976846e-19, 1.22231459e-19]
#            unit: dimensionless,
#            t0: 1187008370.0 s,
#            dt: 0.000244140625 s,
#            name: Strain,
#            channel: None)

# %% [markdown]
# >Uses `event_gps` and `fetch_open_data` to obtain the gps time of GW170817 and then obtain the data for that event

# %% [markdown]
# Now, we can generate our spectrogram using a specific FFT length (remembering to use a window):
#
# <div class="alert alert-info">
# Each of these methods returns the output as stacked power spectral densities, so we take the square root to get back to a familiar amplitude spectral density
# </div>

# %%
specgram = ldata.spectrogram2(fftlength=4, overlap=2, window='hann') ** (1/2.)

plot = specgram.plot()
# Out:
# <Plot size 1200x600 with 1 Axes>

# %% [markdown]
# >Makes a spectrogram using `ldata.spectrogram()` to show off where the hot points are, which are not visible.

# %% [markdown]
# Hmmm... something's not right. Can you spot the only "hot" point in this colormap? Maybe the default scale of the color axis is not suitable to fit the excursion of values in this map. **Pro Tip**: check `specgram.min()` and `specgram.max()` values to see if the previous guess is right or not.
#
# We can fix this by passing a few more arguments to our plot to control the display (especially the colouring):

# %%
ax = plot.gca()
ax.set_yscale('log')
ax.set_ylim(10, 1400)
ax.colorbar(
    clim=(1e-24, 1e-20),
    norm="log",
    label=r"Strain noise [$1/\sqrt{\mathrm{Hz}}$]",
)
plot  # refresh
# Out:
# <Plot size 1200x600 with 2 Axes>

# %% [markdown]
# >Replots the spectrogram using `ax.set_yscale()` to make the y scale logarithmic, `ax.set_ylim()` to change the upper and lower limits of the y axis, and `ax.colorbar()` to change the colors so its easier to see

# %% [markdown]
# Here we can see how the ASD for LIGO-Livingston evolves over a ~17 minute span around GW170817. Four order of magnitudes in the ASD intensity are involved, and this is why the previous attempt resulted in a (almost) fully dark blue image.
#
# We can see that the low-frequency noise (<30 Hz) rumbles along with some variation, but high frequencies (>100 Hz) are relatively stable. Between 30-100 Hz we can see some narrow features appearing and disappearing as non-stationary noise affects the measurement.

# %% [markdown]
# ## Spectrogram challenge!
#
# - download the data for all three detectors involved with the GW170814 detection, generate a PSD for each, and make a plot
# - make a spectrogram of data for 10 minutes around the GW170817 detection for the LIGO-Livingston detector

# %%
from gwosc.datasets import event_gps
from gwpy.timeseries import TimeSeries
from gwpy.plot import Plot
gps = event_gps('GW170814')
h = TimeSeries.fetch_open_data('H1', int(gps)-10, int(gps)+10, cache=True)
l = TimeSeries.fetch_open_data('L1', int(gps)-10, int(gps)+10, cache=True)
v = TimeSeries.fetch_open_data('V1', int(gps)-10, int(gps)+10, cache=True)
hpsd = h.psd(fftlength=4, overlap=2)
lpsd = l.psd(fftlength=4, overlap=2)
vpsd = v.psd(fftlength=4, overlap=2)
plot = Plot(hpsd, lpsd, vpsd)
ax = plot.gca()
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(10, 1400)
ax.set_ylim(1e-48, 1e-40)
ax.legend(['H1', 'L1', 'V1'])
plot.show()
# Out:
# <Plot size 640x480 with 1 Axes>

# %% [markdown]
# >Generates multiple graphs for the psd of sensors H1, V1, and L1 around the event GW170814

# %%
gps = event_gps('GW170817')
ldata1 = TimeSeries.fetch_open_data('L1', int(gps)-300, int(gps)+300, cache=True)
s = ldata1.spectrogram(stride = 4,fftlength=4, overlap=2, window='hann') ** (1/2.)
p = s.plot()
ax = p.gca()
ax.set_yscale('log')
ax.set_ylim(10, 1400)
ax.colorbar(
    clim=(1e-24, 1e-20),
    norm="log",
    label=r"Strain noise [$1/\sqrt{\mathrm{Hz}}$]",
)
p.show()
# Out:
# <Plot size 1200x600 with 2 Axes>

# %% [markdown]
# >Shows spectrogram of 10 minute stretch around event GW170817 using `ldata1.spectrogram()`

# %% [markdown]
# ## Q-transforms in GWpy
#
# The spectrogram above is a useful way to show the variation of a power spectral density (PSD) estimate over time. It's best used to see general trends in how the sensitivity of the GW detectors is changing over longish periods (minutes or hours).
#
# In this section, we will see how we can use a special filter called a Q-transform to create a time-frequency representation of our data that allows use to pick out features at different frequencies, and how they evolve over very short times, without much prior knowledge of the signal morphology.
#
# See [this article](https://doi.org/10.1088/0264-9381/21/20/024) for more details on the Q-transform and its application to gravitational-wave data.

# %% [markdown]
# First, lets reload some data from LIGO Hanford around GW170817:

# %%
segment = (int(gps) - 30, int(gps) + 2)
hdata = TimeSeries.fetch_open_data('H1', *segment, verbose=True, cache=True)
# Out:
# Fetched 1 URLs from gwosc.org for [1187008852 .. 1187008884))
# Reading data... [Done]

# %% [markdown]
# >Fetches data with `TimeSeries.fetch_open_data()` from the H1 detector

# %% [markdown]
# We can now use the `q_transform()` method of the `hdata` `TimeSeries` to create our time-frequency representation (as a [spectrogram](https://gwpy.github.io/docs/stable/spectrogram/)).

# %%
hq = hdata.q_transform(frange=(30, 500))
plot = hq.plot()
plot.colorbar(label="Normalised energy")
# Out:
# <Plot size 1200x600 with 2 Axes>

# %% [markdown]
# >Uses the Q transform (`.q_transform()`) to scan the raw time-series data and cut out the low and high frequency seismic noise and sensor noise to focus on the remaining part.

# %% [markdown]
# From this we can see a different representation of the data. Because the Q-transform returns (by default) normalised energy, the low-frequency rumbling is now much less obvious, and we can see better some noises at higher frequencies.
#
# But, we can clean up the display to better visualise the data:

# %%
ax = plot.gca()
ax.set_epoch(gps)
ax.set_ylim(30, 500)
ax.set_yscale("log")
plot  # refresh
# Out:
# <Plot size 1200x600 with 2 Axes>

# %% [markdown]
# >Changes the axes of the plot using `.gca()`

# %% [markdown]
# Now we can see a more prominent feature starting at ~-6 seconds that looks a little familiar.
# Here we can use our knowledge of the Q-transform, and our hunch about the origin of the 'feature' to choose a more specific range of 'Q' for the Q-transform, so as to better resolve the feature:

# %%
hq = hdata.q_transform(frange=(30, 500), qrange=(100, 110))
plot = hq.plot()
ax = plot.gca()
ax.set_epoch(gps)
ax.set_yscale('log')
ax.colorbar(label="Normalised energy")
# Out:
# <Plot size 1200x600 with 2 Axes>

# %% [markdown]
# > Uses Q transform to make a more specific range of Q

# %% [markdown]
# Now we see the beautiful, clear track of a BNS merger, visible from about -4 seconds (maye -10 if you squint), all the way through to the merger at T=0.
#
# HINT: We can also use the `outseg` option to zoom in around the merger:

# %%
#-- Use OUTSEG for small time range
hq2 = hdata.q_transform(frange=(30, 500), qrange=(80, 110), outseg=(gps-3,gps+0.5))
plot = hq2.plot()
ax = plot.gca()
ax.set_epoch(gps)
ax.set_yscale('log')
ax.colorbar(label="Normalised energy")
# Out:
# <Plot size 1200x600 with 2 Axes>

# %% [markdown]
# > Uses `outseg` to focus the Q transform between -3 seconds to 1 second

# %% [markdown]
# We can repeat the exercise using LIGO-Livingston data to see something even more remarkable.
# First we download and filter the Livingston data:

# %%
ldata = TimeSeries.fetch_open_data('L1', *segment, verbose=True)
# Out:
# Fetched 1 URLs from gwosc.org for [1187008852 .. 1187008884))
# Reading data... [Done]

# %%
lq = ldata.q_transform(frange=(30, 500), qrange=(100, 110))
plot = lq.plot()
ax = plot.gca()
ax.set_epoch(gps)
ax.set_yscale('log')
ax.colorbar(label="Normalised energy")
# Out:
# <Plot size 1200x600 with 2 Axes>

# %% [markdown]
# Now we can see a large blob of energy that is 1000 times louder than what we see in the LIGO-Hanford data.
# As luck would have it, an instrumental glitch almost exactly overlaps the BNS signal in LIGO-Livingston.
# But, we can rescale things to see the astrophyscal signal better:

# %%
plot.colorbars[0].mappable.set_clim(0,20)
plot.show()

# %% [markdown]
# Now we can see the BNS signal track all the way back to T=-28 seconds in LIGO-Livingston data!
#
# However, there is still the large glitch that makes it difficult to see the signal near merger. This loud of a glitch is particularly troublesome for any analyses that want to use this data. In order to address these types of loud glitches, a technique called **gating** is commonly used. We will use the `gwpy.TimeSeries.gate()` method to gate the data.
#
# In order to apply a gate, the data is multiplied by a window function. The `gwpy` method we are using uses an inverse Planck window, but other windows, such as a Tukey window, are also commonly used. After multiplying by the window, the data directly surrounding the glitch will be zeroed. It is also important that the window function includes a transition from 0 to 1 so that there are not any discontinuities introduced. An example of a window function can be seen in the lower panel of Fig. 2 from [the GW170817 discovery paper](https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.119.161101).
#
# An additional feature of `gwpy.TimeSeries.gate()` is that the times that are gated are identified automatically. This is done by finding data points with an absolute value above some threshold in the whitened data. The default threshold is `50`.
#
# Let's now apply gates to the Livingston data and remake the plot:

# %%
gated_ldata = ldata.gate(tzero=0.25, tpad=0.25)

gated_lq = gated_ldata.q_transform(frange=(30, 500), qrange=(100, 110))
plot = gated_lq.plot()
ax = plot.gca()
ax.set_epoch(gps)
ax.set_yscale('log')
ax.colorbar(label="Normalised energy")
plot.colorbars[0].mappable.set_clim(0,20)
# Out:
# <Plot size 1200x600 with 2 Axes>

# %% [markdown]
# >Applied gates to the livingston data with `ldata.gate()`

# %% [markdown]
# Now the signal is a bit easier to see, but some of our data is now missing. Hence gating can be a great way to deal with loud glitches, but only should be used sparingly.
#
# This is basically the same procedure (and the same code) that was used to produce Figures 1 and 2 of the BNS discovery article '_Observation of Gravitational Waves from a Binary Neutron Star Inspiral_' [[link](https://doi.org/10.1103/PhysRevLett.119.161101)]

# %% [markdown]
# ## Q-scan challenge!
#
# - download the data for all detectors involved with the GW170814 detection. Which detectors registered this event?
# - generate a Q-scan for the data in each detector. (Hint: try using a much smaller time range and Q-range than you did for GW170817)

# %%
gps = event_gps("GW170814")
h = TimeSeries.fetch_open_data("H1", int(gps) - 10, int(gps) + 10, cache=True)
l = TimeSeries.fetch_open_data("L1", int(gps) - 10, int(gps) + 10, cache=True)
v = TimeSeries.fetch_open_data("V1", int(gps) - 10, int(gps) + 10, cache=True)

# %% [markdown]
# Detectors H1, L1, and V1 registered the event because no errors happened

# %%
h1 = h.q_transform(outseg=(gps-4, gps+4), qrange=(1, 10), frange = (30,500))
l1 = l.q_transform(outseg=(gps-4, gps+4), qrange=(1, 10),frange = (30,500))
v1 = v.q_transform(outseg=(gps-4, gps+4), qrange=(1, 10),frange = (30,500))
plot_h = h1.plot()
ax_h = plot_h.gca()
ax_h.set_yscale('log')
plot_h.show()
plot_l = l1.plot()
ax_l = plot_l.gca()
ax_l.set_yscale('log')
plot_l.show()
plot_v = v1.plot()
ax_v = plot_v.gca()
ax_v.set_yscale('log')
plot_v.show()
# Out:
# <Plot size 1200x600 with 1 Axes>
# <Plot size 1200x600 with 1 Axes>
# <Plot size 1200x600 with 1 Axes>

# %% [markdown]
# > Uses `q_transform()` to plot the filtered data for all three
